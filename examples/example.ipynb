# %% [markdown]
# ### Example

# %%
import project_path
import minerals_supply_scenarios as mss
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Lithium

# %%
dataset_path = "SPGlobal_Export_8-17-2024_98caab9c-a5b0-4363-b542-b27002037955.xls"

lithium_brine_scenarios = mss.MetalSupplyScenarios(
    commodity="Lithium",
    dataset_path=dataset_path,
    timeframe = (2020,2035,1),
    specifics = {"Deposit Type": ["Brine (Salar)"]},
    exclude = {"Country": ["Canada"]}
    )
# Out:
# Considering only: {'Deposit Type': ['Brine (Salar)']}
# Excluding: {'Country': ['Canada']}
# ****************************************
# Creating supply scenarios for lithium
# Importing raw dataset from S&P database...
# Applying strategy: fill_data_gaps
# Applying strategy: estimate_future_production
# Applying strategy: create_scenarios_data
# Applying strategy: harmonize_production_data
# Exporting premise scenario data file
# *****************************
# Processing report
# Number projects in updated dataset : 140
# Number projects with production in updated dataset : Production 2020     9
# Production 2021     9
# Production 2022    11
# Production 2023    14
# Production 2024    18
# Production 2025    21
# Production 2026    25
# Production 2027    28
# Production 2028    30
# Production 2029    30
# Production 2030    32
# Production 2031    32
# Production 2032    32
# Production 2033    32
# Production 2034    32
# Production 2035    32
# dtype: int64
# ...

# %%
lithium_brine_scenarios.get_production_by_scenario()
# Out:
#                         2020     2021     2022     2023      2024      2025  \
# Scenario
# S&P-Baseline        178.9694  221.946  302.665  321.270  408.1308  455.4636
# S&P-Ambitious       178.9694  227.917  310.626  336.986  445.4298  590.1776
# S&P-Very Ambitious  178.9694  227.917  310.626  336.986  450.4298  617.0806
#
#                        2026     2027     2028     2029      2030      2031  \
# Scenario
# S&P-Baseline        507.768  539.151  556.637  574.589   597.487   589.714
# S&P-Ambitious       693.555  767.521  816.565  836.027   858.925   851.152
# S&P-Very Ambitious  723.444  828.388  916.914  965.528  1044.414  1036.641
#
#                         2032      2033      2034      2035
# Scenario
# S&P-Baseline         589.714   589.714   588.321   580.758
# S&P-Ambitious        851.152   853.748   851.360   843.797
# S&P-Very Ambitious  1036.641  1039.237  1036.849  1029.286

# %%
# Raw dataset as improted from S&P
raw_dataset = lithium_brine_scenarios.sp_dataset_raw

# Dataset updated to fill data gaps in production forecasts
updated_dataset = lithium_brine_scenarios.sp_dataset_updated

# Scenario data
scenarios_data = lithium_brine_scenarios.scenario_data

# Scenario data in premise format
premise_scenarios_data = lithium_brine_scenarios.premise_scenario_data
